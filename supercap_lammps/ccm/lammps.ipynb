# %%
import os
import ase
from ase import io
from ase.visualize import view
from ase import gui 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nglview as nv
import ipywidgets

# %%
systems=io.read('system.dump', format='lammps-dump-text')

# %%
view(systems, viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 272.0">
#     <group/>
#   </viewpoint>
#   <transform translation="-16.1 -17.2 -68.0">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 32.2 0.0 0.0 32.2 34.4 0.0 0.0 34.4 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 136.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 32.2 0.0 0.0 32.2 34.4 0.0 0.0 34.4 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 32.2 0.0 0.0 32.2 0.0 136.0 0.0 0.0 136.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 34.4 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 32.2 0.0 0.0 32.2 0.0 136.0 0.0 0.0 136.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="5.023489800000001 31.673834399999997 61.193336">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 1.0 1.0"/>
#             </appearance>
#             <sphere radius="0.31"/>
#           </shape>
#         </transform>
#         <transform translation="2.9483608000000006 33.4121696 61.24896">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.851 1.0 1.0"/>
#             </appearance>
#             <sphere radius="0.28"/>
#           </shape>
#         </transform>
#         <transform translation="6.8930218000000005 31.1876592 64.490384">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.8 0.502 1.0"/>
#             </appearance>
#             <sphere radius="1.28"/>
#           </shape>
#         </transform>
#         <transform translation="16.5629716 3.01564504 23.840120000000002">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.761 1.0 0.0"/>
#             </appearance>
#             <sphere radius="0.96"/>
#           </shape>
#         </transform>
#         <transform translation="5.360978 2.88904272 28.092704">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 1.0 1.0"/>
#             </appearance>
#             <sphere radius="0.31"/>
#           </shape>
#         </transform>
#         <transform translation="5.8575342 2.85116488 30.754224">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.851 1.0 1.0"/>
#             </appearance>
#             <sphere radius="0.28"/>
#           </shape>
#         </transform>
#         <transform translation="2.43335078 0.7411067199999999 26.902024">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.8 0.502 1.0"/>
#             </appearance>
#             <sphere radius="1.28"/>
#           </shape>
#         </transform>
#         <transform translation="16.518149200000003 2.7517764 35.035232">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.761 1.0 0.0"/>
#             </appearance>
#             <sphere radius="0.96"/>
#           </shape>
#         </transform>
#         <transform translation="17.8630788 26.3123192 42.04576">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 1.0 1.0"/>
#             </appearance>
#             <sphere radius="0.31"/>
#           </shape>
#         </transform>
#         <transform translation="16.1519064 28.274392 41.301975999999996">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.851 1.0 1.0"/>
#             </appearance>
#             <sphere radius="0.28"/>
#           </shape>
#         </transform>
#         <transform translation="17.516413600000003 22.9911368 40.187864000000005">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.8 0.502 1.0"/>
#             </appearance>
#             <sphere radius="1.28"/>
#           </shape>
#         </transform>
#         <transform translation="6.343013600000001 25.2600232 31.393696000000002">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.761 1.0 0.0"/>
#             </appearance>
#             <sphere radius="0.96"/>
#           </shape>
#         </transform>
#         <transform translation="20.9129018 27.709372 31.207648">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 1.0 1.0"/>
#             </appearance>
#             <sphere radius="0.31"/>
#           </shape>
#         </transform>
#         <transform translation="21.646417800000002 30.124011199999998 32.188752">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.851 1.0 1.0"/>
#             </appearance>
#             <sphere radius="0.28"/>
#           </shape>
#         </transform>
#         <transform translation="20.569231200000004 27.4765528 27.408896">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.8 0.502 1.0"/>
#             </appearance>
#             <sphere radius="1.28"/>
#           </shape>
#         </transform>
#         <transform translation="1.5803341400000002 9.8493392 16.918128">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.761 1.0 0.0"/>
#             </appearance>
#             <sphere radius="0.96"/>
#           </shape>
#         </transform>
#         <transform translation="22.0203564 22.226012 29.351656000000002">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 1.0 1.0"/>
#             </appearance>
#             <sphere radius="0.31"/>
#           </shape>
#         </transform>
#         <transform translation="24.727152800000002 22.1884472 29.296984">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.851 1.0 1.0"/>
#             </appearance>
#             <sphere radius="0.28"/>
#           </shape>
#         </transform>
#         <transform translation="20.2859356 22.975794399999998 26.030264000000003">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.8 0.502 1.0"/>
#             </appearance>
#             <sphere radius="1.28"/>
#           </shape>
#         </transform>
#         <transform translation="25.869512200000003 23.8197296 25.99844">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.761 1.0 0.0"/>
#             </appearance>
#             <sphere radius="0.96"/>
#           </shape>
#         </transform>
#         <transform translation="15.911855400000002 7.4566472 37.143912">
#           <shape>
#             <appearance>
#               <material diffuseColor="1.0 1.0 1.0"/>
#             </appearance>
#             <sphere radius="0.31"/>
#           </shape>
#         </transform>
#         <transform translation="14.169320200000001 5.393576 36.947936">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.851 1.0 1.0"/>
#             </appearance>
#             <sphere radius="0.28"/>
#           </shape>
#         </transform>
#         <transform tran

# %%
# !cat settings.mod

# %%
# !more in.conp

# %%
# !head -50 data.graph-il

# %%
# !/ocean/projects/che240027p/shared/software/Team_BSU/lammps-CPM/src/lmp_serial -i in.conq

# %%
df = pd.read_csv('elec_char.txt', sep=' ')

# %%
df.plot(x='time', y=(['anode_char','cathode_char']))

# %%
df1 = pd.read_csv('cat_density.txt',header = None, sep=' ', skiprows=4, names=['distance / A', 'cation density', 'density' ])
df2 = pd.read_csv('an_density.txt',header = None, sep=' ', skiprows=4, names=['distance / A', 'anion density', 'density' ])

# %%
df1.insert(0, 'anion density',df2['anion density'])
df1.plot(x='distance / A', y=(['cation density', 'anion density']))

# %%
cathode_dump=io.read('cathode.dump', format='lammps-dump-text')
anode_dump=io.read('anode.dump', format ='lammps-dump-text')
cathode_charge= cathode_dump.get_initial_charges()
anode_charge=anode_dump.get_initial_charges()
c_per_atom_charge=pd.DataFrame(cathode_charge, columns=['cathode'])
a_per_atom_charge=pd.DataFrame(anode_charge, columns=['anode'])
a_per_atom_charge.insert(0, 'cathode',c_per_atom_charge['cathode'])

# %%
a_per_atom_charge.plot(y=(['anode','cathode']))
